# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read Csv Dataset

Data = pd.read_csv('Netflix_Dataset.csv')
Data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# ...

# %%
## Explore the data

# %%
Data.shape
# Out:
# (7789, 11)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
Data.describe()
# Out:
#        Show_Id Category              Title                 Director  \
# count     7789     7789               7789                     5401
# unique    7787        2               7787                     4050
# top      s6621    Movie  The Lost Okoroshi  RaÃºl Campos, Jan Suter
# freq         2     5379                  2                       18
#
#                       Cast        Country     Release_Date Rating  Duration  \
# count                 7071           7282             7779   7782      7789
# unique                6831            681             1565     14       216
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    18           2556              118   2865      1608
#
#                  Type                                        Description
# count            7789                                               7789
# unique            492                                               7769
# ...

# %%
# Size of Data

Data.size
# Out:
# 85679

# %%
# Columns in Dataset

Data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# Data Type
Data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
num_entries = len(Data)
print(f"Number of entries in the dataset: {num_entries}")
# Out:
# 7789

# %%
## Number of Unique Titles:

unique_title = Data['Title'].nunique()
print('Unique title are', unique_title)
# Out:
# Unique title are 7787

# %%
# Number of Movies and TV Shows
Data['Category'].value_counts()
# Out:
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
## Top 10 Directors

Data['Director'].value_counts().head(10)
# Out:
# RaÃºl Campos, Jan Suter    18
# Marcus Raboy               16
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Jay Chapman                12
# Youssef Chahine            12
# Martin Scorsese            12
# Steven Spielberg           10
# David Dhawan                9
# Robert Rodriguez            8
# Name: Director, dtype: int64

# %%
## No of titles released in each country

Data['Country'].value_counts()
# Out:
# United States                                                   2556
# India                                                            923
# United Kingdom                                                   397
# Japan                                                            226
# South Korea                                                      183
#                                                                 ...
# Russia, United States, China                                       1
# Italy, Switzerland, France, Germany                                1
# United States, United Kingdom, Canada                              1
# United States, United Kingdom, Japan                               1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: Country, Length: 681, dtype: int64

# %%
### Distribution of rating
Data['Rating'].value_counts()
# Out:
# TV-MA       2865
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: Rating, dtype: int64

# %%
# Is there any Duplicate records in dataset ? if yes, then remove the duplicate record .

# %%
Data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
## Lets find the duplicate record in dataset

Data[Data.duplicated]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
## To  drop duplicates
Data.drop_duplicates(inplace =True)

# %%
Data.shape
## 2 duplicates dropped from the dataset
# Out:
# (7787, 11)

# %% [markdown]
# ### 2 .. If there any null value present ? show with heatmap

# %%
checknull = Data.isnull()
checknull
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
Data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# Lets shows null value with heatmap

# sns.heatmap(Data.isnull())

sns.heatmap(checknull)
# Out:
# <Axes: >

# %%
sns.heatmap(checknull, cmap='viridis')
# Out:
# <Axes: >

# %%
 Data.head(100)
# Out:
#    Show_Id Category           Title           Director  \
# 0       s1  TV Show              3%                NaN
# 1       s2    Movie           07:19  Jorge Michel Grau
# 2       s3    Movie           23:59       Gilbert Chan
# 3       s4    Movie               9        Shane Acker
# 4       s5    Movie              21     Robert Luketic
# ..     ...      ...             ...                ...
# 95     s96  TV Show        28 Moons                NaN
# 96     s97    Movie  3 Days to Kill                McG
# 97     s98    Movie     3 Deewarein    Nagesh Kukunoor
# 98     s99    Movie   3 Generations        Gaby Dellal
# 99    s100    Movie      3 Heroines     Iman Brotoseno
#
#                                                  Cast  \
# 0   JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# 1   DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...
# ...

# %% [markdown]
# ### for 3 Days to Kill , whats the show_id and who is the director and duration of show

# %%
Details = Data[Data['Title']=='3 Heroines']
Details
# Out:
#    Show_Id Category       Title        Director  \
# 99    s100    Movie  3 Heroines  Iman Brotoseno
#
#                                                  Cast    Country  \
# 99  Reza Rahadian, Bunga Citra Lestari, Tara Basro...  Indonesia
#
#        Release_Date Rating Duration  \
# 99  January 5, 2019  TV-PG  124 min
#
#                                            Type  \
# 99  Dramas, International Movies, Sports Movies
#
#                                           Description
# 99  Three Indonesian women break records by becomi...

# %%
print(Details[['Title','Show_Id','Director','Duration']])
# Out:
#          Title Show_Id        Director Duration
# 99  3 Heroines    s100  Iman Brotoseno  124 min

# %% [markdown]
# ### In which year highest number of Tv shows and movies were released ? show with bar graphs

# %%
Data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
Data['Date_N']=pd.to_datetime(Data['Release_Date'])

# %%
Data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
#  11  Date_N        7777 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(11)
# memory usage: 790.9+ KB

# %%
Data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
Data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### How many movies and Tv shows in the dataset . show with graph

# %%
Data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...  Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
Data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
Data.groupby('Category').Category.count().plot(kind='bar',)
# Out:
# <Axes: xlabel='Category'>

# %%
## Year of film released

# %%
Data['Year']=Data['Date_N'].dt.year

# %%
Data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...  Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
## Filtering 
Data[(Data['Category']=='Movie') & (Data['Year']==2009)]
# Out:
#      Show_Id Category                    Title      Director  \
# 3248   s3249    Movie  Just Another Love Story  Ole Bornedal
# 5766   s5766    Movie                 Splatter     Joe Dante
#
#                                                    Cast        Country  \
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
#
#            Release_Date Rating Duration                          Type  \
# 3248        May 5, 2009  TV-MA  104 min  Dramas, International Movies
# 5766  November 18, 2009  TV-MA   29 min                 Horror Movies
#
#                                             Description     Date_N    Year
# 3248  When he causes a car accident that leaves a yo... 2009-05-05  2009.0
# 5766  After committing suicide, a washed-up rocker r... 2009-11-18  2009.0

# %% [markdown]
# ### sHOW TITLE OF TV SHOWS THAT RELEASED IN INDIA ONLY

# %%
Data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# Details_show = Data['Category']=='TV Show' & (Data['Country']== 'India')]['Title']

Data[(Data['Category']=='TV Show') & (Data['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                          AkbarÂ Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Show all records where category is movie , type is comedy amd country is India

# %%
Data[(Data['Category']=='Movie') & (Data['Type']=='Comedies') | (Data['Country']=='India')]

## Filtering and or operation
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie  â€‹â€‹Kuch Bheege Alfaaz                Onir
# 21       s22    Movie            â€‹Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %% [markdown]
# ### In how many movies or show Anupam Kher was cast

# %%
# Data[Data['Cast']=='Anupam Kher']

Data['Cast']
# Out:
# 0       JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# 1       DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7784    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                              Nasty C
# 7787                           Adriano Zumbo, Rachel Khoo
# 7788                                                  NaN
# Name: Cast, Length: 7789, dtype: object

# %% [markdown]
# ### Titles Released in a Specific Country:

# %%
filter_country = 'India'
Titles_in_country = Data[Data['Country']==filter_country]
Titles_in_country[['Title','Release_Date','Country']]
# Out:
#                          Title        Release_Date Country
# 8                          706       April 1, 2019   India
# 9                         1920   December 15, 2017   India
# 18                      15-Aug      March 29, 2019   India
# 20    â€‹â€‹Kuch Bheege Alfaaz   September 1, 2018   India
# 21              â€‹Goli Soda 2  September 15, 2018   India
# ...                        ...                 ...     ...
# 7766                      Zero        May 21, 2019   India
# 7771  Zindagi Na Milegi Dobara   December 15, 2019   India
# 7778                  Zokkomon    November 1, 2018   India
# 7782                       Zoo        July 1, 2018   India
# 7785                    Zubaan       March 2, 2019   India
#
# [923 rows x 3 columns]

# %% [markdown]
# ### Titles Directed by a Specific Director:

# %%
Filter_Dir= 'Aanand Rai'
Title_Dire_country = Data[Data['Director']==Filter_Dir]
Title_Dire_country[['Category','Title' , 'Release_Date','Cast']]
# Out:
#      Category           Title  Release_Date  \
# 5983    Movie  Tanu Weds Manu  July 5, 2020
# 7766    Movie            Zero  May 21, 2019
#
#                                                    Cast
# 5983  Madhavan, Kangana Ranaut, Jimmy Shergill, Deep...
# 7766  Shah Rukh Khan, Anushka Sharma, Katrina Kaif, ...

# %%
Title_Dire_country = Data[Data['Director']=='Aanand Rai']
Title_Dire_country[['Category','Title' , 'Release_Date','Cast']]
# Out:
#      Category           Title  Release_Date  \
# 5983    Movie  Tanu Weds Manu  July 5, 2020
# 7766    Movie            Zero  May 21, 2019
#
#                                                    Cast
# 5983  Madhavan, Kangana Ranaut, Jimmy Shergill, Deep...
# 7766  Shah Rukh Khan, Anushka Sharma, Katrina Kaif, ...

# %% [markdown]
# ### Titles with a Specific Duraton:

# %%
Title_duration= Data[Data['Duration'] =='128 min']
Title_duration[['Title' , 'Category' , 'Duration']]
# Out:
#                                 Title Category Duration
# 21                     â€‹Goli Soda 2    Movie  128 min
# 481                               Amy    Movie  128 min
# 514                  Angamaly Diaries    Movie  128 min
# 758                    Basic Instinct    Movie  128 min
# 1153                          BuyBust    Movie  128 min
# 1689                          Delhi 6    Movie  128 min
# 1732                          Dhamaal    Movie  128 min
# 1988  EMI: Liya Hai To Chukana Padega    Movie  128 min
# 2326                   Gabbar Is Back    Movie  128 min
# 2768                  Holding the Man    Movie  128 min
# 2912                I Hate Luv Storys    Movie  128 min
# 2943              III Smoking Barrels    Movie  128 min
# 3129                 Jatts in Golmaal    Movie  128 min
# 3191      Jo Pil-ho: The Dawning Rage    Movie  128 min
# 3245                Jupiter Ascending    Movie  128 min
# 3297                          Kaminey    Movie  128 min
# ...

# %% [markdown]
# ### Titles Released in a Specific Year:

# %%
Title_year = Data[Data['Release_Date']=='August 14, 2020']
Title_year[['Show_Id','Title','Release_Date']]
# Out:
#      Show_Id                                              Title  \
# 0         s1                                                 3%
# 877     s878  Beyond the Boundary: ICC Women's T20 World Cup...
# 2138   s2139                                           Fearless
# 2441   s2442                                            Glow Up
# 4462   s4463                                    Nigerian Prince
# 4569   s4570                 Octonauts & the Caves of Sac Actun
# 4988   s4988                                      Project Power
# 6012   s6012                             Teenage Bounty Hunters
# 6423   s6422                                    The Great Heist
# 6586   s6585                                The Legend of Korra
# 7777   s7776                                         Zoids Wild
#
#          Release_Date
# 0     August 14, 2020
# 877   August 14, 2020
# 2138  August 14, 2020
# 2441  August 14, 2020
# 4462  August 14, 2020
# 4569  August 14, 2020
# 4988  August 14, 2020
# ...

# %%
Data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...  Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %% [markdown]
# ### Titles with Short Durations (e.g., less than 90 minutes)

# %%
Short_duration =Data[Data['Duration']>'90 min']
Short_duration[['Title','Country','Duration']]
# Out:
#                               Title  \
# 1                             07:19
# 6                               122
# 14                             3022
# 27                           #Alive
# 28    #AnneFrank - Parallel Stories
# ...                             ...
# 7749                   Ø§Ø´ØªØ¨Ø§Ùƒ
# 7763                         Zapped
# 7772                        Zinzana
# 7782                            Zoo
# 7784                           Zozo
#
#                                                 Country Duration
# 1                                                Mexico   93 min
# 6                                                 Egypt   95 min
# 14                                        United States   91 min
# 27                                          South Korea   99 min
# 28                                                Italy   95 min
# ...                                                 ...      ...
# 7749                                      Egypt, France   98 min
# ...
